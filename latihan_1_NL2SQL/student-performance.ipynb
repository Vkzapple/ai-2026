# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'student_performance.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      500 non-null    object
#  1   gender          500 non-null    object
#  2   age             500 non-null    int64
#  3   study_hours     500 non-null    float64
#  4   attendance_pct  450 non-null    float64
#  5   sleep_hours     500 non-null    float64
#  6   final_score     500 non-null    float64
#  7   passed          500 non-null    int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 31.4+ KB

# %%
df.isnull().sum()
# Out:
# student_id         0
# gender             0
# age                0
# study_hours        0
# attendance_pct    50
# sleep_hours        0
# final_score        0
# passed             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               age  study_hours  attendance_pct  sleep_hours  final_score  \
# count  500.000000   500.000000      450.000000    500.00000   500.000000
# mean    16.476000     5.338400       76.030444      6.97940    69.988800
# std      1.150683     2.570147       14.773239      1.72328    17.147215
# min     15.000000     1.000000       50.300000      4.00000    40.100000
# 25%     15.000000     3.100000       62.175000      5.40000    56.075000
# 50%     16.000000     5.200000       77.150000      7.10000    69.800000
# 75%     18.000000     7.525000       88.950000      8.40000    84.600000
# max     18.000000    10.000000      100.000000     10.00000    99.700000
#
#            passed
# count  500.000000
# mean     0.678000
# std      0.467711
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('korelasi heatmap')
# Out:
# Text(0.5, 1.0, 'korelasi heatmap')

# %%
df.skew(numeric_only=True)
# Out:
# age               0.043023
# study_hours       0.104409
# attendance_pct   -0.111943
# sleep_hours      -0.017254
# final_score       0.001578
# passed           -0.764211
# dtype: float64

# %%
df['final_score'].hist()
plt.title('distribusi final_score')
# Out:
# Text(0.5, 1.0, 'distribusi final_score')

# %%
df.isnull().sum() / len(df) * 100
# Out:
# student_id         0.0
# gender             0.0
# age                0.0
# study_hours        0.0
# attendance_pct    10.0
# sleep_hours        0.0
# final_score        0.0
# passed             0.0
# dtype: float64

# %%
df['attendance_pct'].fillna(df['attendance_pct'].median(), inplace=True)
# Out:
# C:\Users\evell\AppData\Local\Temp\ipykernel_10248\4194119852.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['attendance_pct'].fillna(df['attendance_pct'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id        0
# gender            0
# age               0
# study_hours       0
# attendance_pct    0
# sleep_hours       0
# final_score       0
# passed            0
# dtype: int64

# %%
df.to_csv('student-performance_cleanv2.csv', index=False)
print('data sudah berhasil disimpan')
# Out:
# data sudah berhasil disimpan
